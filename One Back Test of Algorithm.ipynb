# %%
bt = get_backtest('5f81f9be6b1e144667109818')
bt.create_full_tear_sheet()
# Out:
# 100% Time:  0:00:10|##########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2014-01-06</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2015-07-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>18</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>4.076%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>6.462%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>2.796%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.44</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.52</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.75</td>
#     </tr>
#     <tr>
# ...
